# %% [markdown]
# #  Welcome to Pandas Tutorial

# %%
import numpy as np
import pandas as pd

# %%
dict1 =  {
    "name":['harry','rohan','skillf'],
    "marks": [51,42,32],
    "city":['rampur','kolkata','brailly'] 
}

# %%
df= pd.DataFrame(dict1)  #making dataframe from dictionary

# %%
df.to_csv("frdns.csv",index=False) #writing to csv

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     51   rampur
# 1  rohan     42  kolkata

# %%
df.tail(1)
# Out:
#      name  marks     city
# 2  skillf     32  brailly

# %%
df.describe() #describe all statistics data
# Out:
#            marks
# count   3.000000
# mean   41.666667
# std     9.504385
# min    32.000000
# 25%    37.000000
# 50%    42.000000
# 75%    46.500000
# max    51.000000

# %%
file = pd.read_csv('frdns.csv')
file
# Out:
#      name  marks     city
# 0   harry     51   rampur
# 1   rohan     42  kolkata
# 2  skillf     32  brailly

# %%
file['marks'][0] = 120
file
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_20612\1569864261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file['marks'][0] = 120
#      name  marks     city
# 0   harry    120   rampur
# 1   rohan     42  kolkata
# 2  skillf     32  brailly

# %%
file.index = ['1st','2nd','3rd']
file
# Out:
#        name  marks     city
# 1st   harry    120   rampur
# 2nd   rohan     42  kolkata
# 3rd  skillf     32  brailly

# %%
ser = pd.Series(np.arange(27,55,2))  # making a series
ser.head(3)
# Out:
# 0    27
# 1    29
# 2    31
# dtype: int32

# %% [markdown]
# ### adding series together

# %%
ser1 = pd.Series(np.arange(27, 55, 2))
ser2 = pd.Series(np.arange(100, 128, 2))
dataframe = pd.DataFrame({'Column1': ser1, 'Column2': ser2})
dataframe # adding multiple series to make a dataset
# Out:
#     Column1  Column2
# 0        27      100
# 1        29      102
# 2        31      104
# 3        33      106
# 4        35      108
# 5        37      110
# 6        39      112
# 7        41      114
# 8        43      116
# 9        45      118
# 10       47      120
# 11       49      122
# 12       51      124
# 13       53      126

# %% [markdown]
# ### adding new series in dataframe

# %%
data = {
    'Column1': [1, 2, 3],
    'Column2': [4, 5, 6]
}
dataframe = pd.DataFrame(data)

new_series = pd.Series([7, 8, 9])

dataframe['NewColumn'] = new_series
dataframe
# Out:
#    Column1  Column2  NewColumn
# 0        1        4          7
# 1        2        5          8
# 2        3        6          9

# %% [markdown]
# #### using pd.concat

# %%
data = {
    'Column1': [1, 2, 3],
    'Column2': [4, 5, 6]
}
df = pd.DataFrame(data)

new_series = pd.Series([7, 8, 9])

dataframe = pd.concat([df, new_series], axis=1)

dataframe.columns = ['Column1', 'Column2', 'NewColumn']
dataframe
# Out:
#    Column1  Column2  NewColumn
# 0        1        4          7
# 1        2        5          8
# 2        3        6          9

# %% [markdown]
# ## Working on NYC_weather csv

# %%
df = pd.read_csv(r'nyc_weather.csv')
df.head(10)
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn
# 0   1/1/2016           38        23        52                 30.03  \
# 1   1/2/2016           36        18        46                 30.02
# 2   1/3/2016           40        21        47                 29.86
# 3   1/4/2016           25         9        44                 30.05
# 4   1/5/2016           20        -3        41                 30.57
# 5   1/6/2016           33         4        35                 30.50
# 6   1/7/2016           39        11        33                 30.28
# 7   1/8/2016           39        29        64                 30.20
# 8   1/9/2016           44        38        77                 30.16
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events
# 0               10           8.0               0           5    NaN  \
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
# 5               10           4.0               0           0    NaN
# 6               10           2.0               0           3    NaN
# 7               10           4.0               0           8    NaN
# 8                9           8.0               T           8   Rain
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333
# 5             259
# 6             293
# 7              79
# 8              76
# 9             109

# %% [markdown]
# ##### what is the max temperature ?

# %%
df['Temperature'].max()
# Out:
# 50

# %% [markdown]
# ##### which days it rains ?

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %% [markdown]
# ##### what is avg wind speed ?

# %%
df['WindSpeedMPH'].mean() 
# something is wrong...because of N/A values in 'WindSpeedMPH'
# Out:
# 6.892857142857143

# %% [markdown]
# ##### data cleaning...

# %%
df.fillna(0,inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %%
# selected rows selected colms
df.loc[0:2, ['EST', 'Temperature']]
# Out:
#         EST  Temperature
# 0  1/1/2016           38
# 1  1/2/2016           36
# 2  1/3/2016           40

# %%
df.describe().loc['count'] # geting only count from describe
# Out:
# Temperature             31.0
# DewPoint                31.0
# Humidity                31.0
# Sea Level PressureIn    31.0
# VisibilityMiles         31.0
# WindSpeedMPH            31.0
# CloudCover              31.0
# WindDirDegrees          31.0
# Name: count, dtype: float64

# %%
df[df.Temperature >= 40]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn
# 2    1/3/2016           40        21        47                 29.86  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events
# 2                10           8.0               0           1      0  \
# 8                 9           8.0               T           8   Rain
# 9                 4           0.0             1.8           7   Rain
# 14                9           5.0               T           2      0
# 15                8           7.0            0.24           7   Rain
# 25               10           7.0               0           2      0
# 26               10           7.0               T           3   Rain
# 30               10           5.0               0           0      0
#
#     WindDirDegrees
# 2              277
# 8               76
# 9              109
# 14             101
# 15             340
# 25             244
# 26             311
# 30             241

# %%
df[['EST','Temperature']][df.Temperature == df.Temperature.max()] #getting all max temps
# Out:
#          EST  Temperature
# 9  1/10/2016           50

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
# change index
df.rename(columns={'EST': 'days'}, inplace=True)
df.set_index('days',inplace=True)
df
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn
# days
# 1/1/2016            38        23        52                 30.03  \
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# 1/14/2016           30        12        47                 29.95
# 1/15/2016           43        31        62                 29.82
# 1/16/2016           47        37        70                 29.52
# 1/17/2016           36        23        66                 29.78
# 1/18/2016           25         6        53                 29.83
# 1/19/2016           22         3        42                 30.03
# 1/20/2016           32        15        49                 30.13
# 1/21/2016           31        11        45                 30.15
# 1/22/2016           26         6        41                 30.21
# 1/23/2016           26        21        78                 29.77
# 1/24/2016           28        11        53                 29.92
# 1/25/2016           34        18        54                 30.25
# 1/26/2016           43        29        56                 30.03
# 1/27/2016           41        22        45                 30.03
# 1/28/2016           37        20        51                 29.90
# 1/29/2016           36        21        50                 29.58
# 1/30/2016           34        16        46                 30.01
# 1/31/2016           46        28        52                 29.90
#
#            VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover
# days
# 1/1/2016                10           8.0               0           5  \
# 1/2/2016                10           7.0               0           3
# 1/3/2016                10           8.0               0           1
# 1/4/2016                10           9.0               0           3
# 1/5/2016                10           5.0               0           0
# 1/6/2016                10           4.0               0           0
# 1/7/2016                10           2.0               0           3
# 1/8/2016                10           4.0               0           8
# 1/9/2016                 9           8.0               T           8
# 1/10/2016                4           0.0             1.8           7
# 1/11/2016               10           0.0               0           1
# 1/12/2016               10           6.0               T           4
# 1/13/2016               10          10.0               0           0
# 1/14/2016               10           5.0               T           7
# 1/15/2016                9           5.0               T           2
# 1/16/2016                8           7.0            0.24           7
# 1/17/2016                8           6.0            0.05           6
# 1/18/2016                9          12.0               T           2
# 1/19/2016               10          11.0               0           1
# 1/20/2016               10           6.0               0           2
# 1/21/2016               10           6.0               0           1
# 1/22/2016                9           0.0            0.01           3
# 1/23/2016                1          16.0            2.31           8
# 1/24/2016                8           6.0               T           3
# 1/25/2016               10           3.0               0           2
# 1/26/2016               10           7.0               0           2
# 1/27/2016               10           7.0               T           3
# 1/28/2016               10           5.0               0           1
# 1/29/2016               10           8.0               0           4
# 1/30/2016               10           7.0               0           0
# 1/31/2016               10           5.0               0           0
#
#              Events  WindDirDegrees
# days
# 1/1/2016          0             281
# 1/2/2016          0             275
# 1/3/2016          0             277
# 1/4/2016          0             345
# 1/5/2016          0             333
# 1/6/2016          0             259
# 1/7/2016          0             293
# 1/8/2016          0              79
# 1/9/2016       Rain              76
# 1/10/2016      Rain             109
# 1/11/2016         0             289
# 1/12/2016         0             235
# 1/13/2016         0             284
# 1/14/2016         0             266
# 1/15/2016         0             101
# 1/16/2016      Rain             340
# 1/17/2016  Fog-Snow             345
# 1/18/2016      Snow             293
# 1/19/2016         0             293
# 1/20/2016         0             302
# 1/21/2016         0             312
# 1/22/2016      Snow              34
# 1/23/2016  Fog-Snow              42
# 1/24/2016      Snow             327
# 1/25/2016         0             286
# 1/26/2016         0             244
# 1/27/2016      Rain             311
# 1/28/2016         0             234
# 1/29/2016         0             298
# 1/30/2016         0             257
# 1/31/2016         0             241

# %%
df.loc['1/13/2016']
# Out:
# Temperature                26
# DewPoint                    4
# Humidity                   42
# Sea Level PressureIn    29.94
# VisibilityMiles            10
# WindSpeedMPH             10.0
# PrecipitationIn             0
# CloudCover                  0
# Events                      0
# WindDirDegrees            284
# Name: 1/13/2016, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#          days  Temperature  DewPoint  Humidity  Sea Level PressureIn
# 0    1/1/2016           38        23        52                 30.03  \
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events
# 0                10           8.0               0           5         0  \
# 1                10           7.0               0           3         0
# 2                10           8.0               0           1         0
# 3                10           9.0               0           3         0
# 4                10           5.0               0           0         0
# 5                10           4.0               0           0         0
# 6                10           2.0               0           3         0
# 7                10           4.0               0           8         0
# 8                 9           8.0               T           8      Rain
# 9                 4           0.0             1.8           7      Rain
# 10               10           0.0               0           1         0
# 11               10           6.0               T           4         0
# 12               10          10.0               0           0         0
# 13               10           5.0               T           7         0
# 14                9           5.0               T           2         0
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1         0
# 19               10           6.0               0           2         0
# 20               10           6.0               0           1         0
# 21                9           0.0            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2         0
# 25               10           7.0               0           2         0
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1         0
# 28               10           8.0               0           4         0
# 29               10           7.0               0           0         0
# 30               10           5.0               0           0         0
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.set_index('Events',inplace=True)

# %%
df.loc['Rain']
# Out:
#              days  Temperature  DewPoint  Humidity  Sea Level PressureIn
# Events
# Rain     1/9/2016           44        38        77                 30.16  \
# Rain    1/10/2016           50        46        71                 29.59
# Rain    1/16/2016           47        37        70                 29.52
# Rain    1/27/2016           41        22        45                 30.03
#
#         VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover
# Events
# Rain                  9           8.0               T           8  \
# Rain                  4           0.0             1.8           7
# Rain                  8           7.0            0.24           7
# Rain                 10           7.0               T           3
#
#         WindDirDegrees
# Events
# Rain                76
# Rain               109
# Rain               340
# Rain               311

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#   Events      days  Temperature  DewPoint  Humidity  Sea Level PressureIn
# 0      0  1/1/2016           38        23        52                 30.03  \
# 1      0  1/2/2016           36        18        46                 30.02
# 2      0  1/3/2016           40        21        47                 29.86
# 3      0  1/4/2016           25         9        44                 30.05
# 4      0  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  WindDirDegrees
# 0               10           8.0               0           5             281
# 1               10           7.0               0           3             275
# 2               10           8.0               0           1             277
# 3               10           9.0               0           3             345
# 4               10           5.0               0           0             333
